# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# load the dataset
cancer = load_breast_cancer()

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.2, random_state=42)
from sklearn.svm import SVC

# create an SVM classifier
svm = SVC(kernel='linear', C=1)

# train the classifier
svm.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
from sklearn.metrics import accuracy_score, classification_report

# make predictions on the testing data
y_pred = svm.predict(X_test)

# calculate the accuracy and print the classification report of the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

report = classification_report(y_test, y_pred)
print("Classification report:\n", report)
# Out:
# Accuracy: 0.956140350877193
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        43
#            1       0.95      0.99      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
# !pip install mlxtend

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions


# plot the decision boundary
clf = SVC(C=100,gamma=0.0001)
pca = PCA(n_components = 2)
X_train2 = pca.fit_transform(X_train)
clf.fit(X_train2, y_train)
plot_decision_regions(X_train2, y_train, clf=clf, legend=2)

plt.xlabel('mean radius')
plt.ylabel('mean texture')
plt.title('SVM decision boundary')
plt.show()
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#                                               0.0/1.4 MB ? eta -:--:--
#                                               0.0/1.4 MB ? eta -:--:--
#                                               0.0/1.4 MB ? eta -:--:--
#      ---                                      0.1/1.4 MB 939.4 kB/s eta 0:00:02
#      ----                                     0.1/1.4 MB 853.3 kB/s eta 0:00:02
#      -----                                    0.2/1.4 MB 908.0 kB/s eta 0:00:02
#      --------                                 0.3/1.4 MB 1.0 MB/s eta 0:00:02
#      ----------                               0.4/1.4 MB 1.1 MB/s eta 0:00:01
#      ------------                             0.4/1.4 MB 1.1 MB/s eta 0:00:01
#      -------------                            0.5/1.4 MB 1.2 MB/s eta 0:00:01
#      ----------------                         0.6/1.4 MB 1.2 MB/s eta 0:00:01
#      -------------------                      0.7/1.4 MB 1.3 MB/s eta 0:00:01
#      ---------------------                    0.7/1.4 MB 1.3 MB/s eta 0:00:01
#      ----------------------                   0.8/1.4 MB 1.3 MB/s eta 0:00:01
#      -----------------------                  0.8/1.4 MB 1.3 MB/s eta 0:00:01
#      -------------------------                0.9/1.4 MB 1.2 MB/s eta 0:00:01
#      --------------------------               0.9/1.4 MB 1.2 MB/s eta 0:00:01
#      --------------------------               0.9/1.4 MB 1.2 MB/s eta 0:00:01
#      -----------------------------            1.0/1.4 MB 1.2 MB/s eta 0:00:01
#      ------------------------------           1.0/1.4 MB 1.2 MB/s eta 0:00:01
#      --------------------------------         1.1/1.4 MB 1.2 MB/s eta 0:00:01
#      ----------------------------------       1.2/1.4 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------     1.2/1.4 MB 1.2 MB/s eta 0:00:01
#      --------------------------------------   1.3/1.4 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\rohan\anaconda3\lib\site-packages (from mlxtend) (1.22.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\rohan\anaconda3\lib\site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\rohan\anaconda3\lib\site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\rohan\appdata\roaming\python\python39\site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\rohan\anaconda3\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: setuptools in c:\users\rohan\anaconda3\lib\site-packages (from mlxtend) (67.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohan\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rohan\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\rohan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rohan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rohan\anaconda3\lib\site-packages)
